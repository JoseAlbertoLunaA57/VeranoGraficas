# %% [markdown]
# # Ejemplo: Grafica de Pastel

# %%
indice:

# %%
import matplotlib.pyplot as plt

# Datos para la gráfica
labels = ['Manzanas', 'Bananas', 'Cerezas', 'Fresas']
sizes = [15, 30, 45, 10]  # Porcentajes
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.1, 0, 0, 0)  # "explotar" la primera porción

# Crear la gráfica de pastel
plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Igualar el aspecto de la gráfica
plt.title('Distribución de Frutas')
plt.show()
